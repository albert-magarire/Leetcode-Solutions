# %% [markdown]
# <a href="https://colab.research.google.com/github/albert-magarire/Leetcode-Solutions/blob/main/Big_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df['Cabin'])
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df.drop('Cabin', axis = 1, inplace = True)

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.drop(["PassengerId","Name", "Ticket"], axis = 1, inplace = True)

# %%
df['Sex'] = LabelEncoder().fit_transform(df['Sex'])
print(df['Sex'])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
X = df.drop("Survived", axis = 1)
Y = df["Survived"]
print(X)
print(Y)
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 0         3    1  22.000000      1      0   7.2500        S
# 1         1    0  38.000000      1      0  71.2833        C
# 2         3    0  26.000000      0      0   7.9250        S
# 3         1    0  35.000000      1      0  53.1000        S
# 4         3    1  35.000000      0      0   8.0500        S
# ..      ...  ...        ...    ...    ...      ...      ...
# 886       2    1  27.000000      0      0  13.0000        S
# 887       1    0  19.000000      0      0  30.0000        S
# 888       3    0  29.699118      1      2  23.4500        S
# 889       1    1  26.000000      0      0  30.0000        C
# 890       3    1  32.000000      0      0   7.7500        Q
#
# [891 rows x 7 columns]
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
display(X_train_scaled[:5])
display(X_test_scaled[:5])
# Out:
# array([[-1.61413602,  0.7243102 ,  1.22920747, -0.47072241, -0.47934164,
#         -0.07868358, -0.30335547,  0.59248936],
#        [-0.40055118,  0.7243102 , -0.50350514, -0.47072241, -0.47934164,
#         -0.37714494, -0.30335547,  0.59248936],
#        [ 0.81303367,  0.7243102 ,  0.18957991, -0.47072241, -0.47934164,
#         -0.47486697, -0.30335547,  0.59248936],
#        [ 0.81303367,  0.7243102 , -0.27247679,  0.37992316, -0.47934164,
#         -0.47623026, -0.30335547,  0.59248936],
#        [ 0.81303367, -1.38062393, -1.81266577,  2.93185988,  2.04874166,
#         -0.02524937, -0.30335547,  0.59248936]])
# array([[ 0.81303367,  0.7243102 ,  0.01239022,  0.37992316,  0.78470001,
#         -0.33390078, -0.30335547, -1.68779402],
#        [-0.40055118,  0.7243102 ,  0.11257046, -0.47072241, -0.47934164,
#         -0.42528387, -0.30335547,  0.59248936],
#        [ 0.81303367,  0.7243102 , -0.73453348, -0.47072241, -0.47934164,
# ...

# %%
X_train = pd.get_dummies(X_train, columns=['Embarked'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['Embarked'], drop_first=True)
display(X_train.head())
display(X_test.head())
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S
# 331       1    1  45.5      0      0  28.5000       False        True
# 733       2    1  23.0      0      0  13.0000       False        True
# 382       3    1  32.0      0      0   7.9250       False        True
# 704       3    1  26.0      1      0   7.8542       False        True
# 813       3    0   6.0      4      2  31.2750       False        True
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S
# 709       3    1  29.699118      1      1  15.2458       False       False
# 439       2    1  31.000000      0      0  10.5000       False        True
# 840       3    1  20.000000      0      0   7.9250       False        True
# 720       2    0   6.000000      0      1  33.0000       False        True
# 39        3    0  14.000000      1      0  11.2417       False       False
